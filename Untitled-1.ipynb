# %%
import qiskit

# %%
qiskit.__version__
# Out:
# '1.1.1'

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
service=QiskitRuntimeService(channel="ibm_quantum",# ibm_cloud
token="5037bf5017c485908ac9fb84ac1e10d62b200085737eeae7e1e550b9d8639ab23e6ae53c2fa868c018e797046978a73bc138b2f06120b4110ea6e20517d96727")

# %%
QiskitRuntimeService.save_account(channel="ibm_quantum",
token="5037bf5017c485908ac9fb84ac1e10d62b200085737eeae7e1e550b9d8639ab23e6ae53c2fa868c018e797046978a73bc138b2f06120b4110ea6e20517d96727")

# %%
backend = service.backend(name="ibm_brisbane")

# %%
backend.num_qubits
# Out:
# 127

# %%
# Hello World in quantum now!
# Episode 3 https://www.youtube.com/watch?v=93-zLTppFZw&list=PLOFEBzvs-VvrgHZt3exM_NNiNKtZlHvZi&index=4

# 1. Map the problem to Circuits and Operators
# 2. Optimize the circuit
# 3. Execute it on the backend
# 4. Post-Process the Results

# %% [markdown]
# # Do the Hello World example on a 2-qbit Bell state

# %% [markdown]
# ## Step1: Map the problem to circuits and operators

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0,1)
qc.draw(output="mpl")

# %%
from qiskit.quantum_info import Pauli

ZZ=Pauli('ZZ')
ZI=Pauli('ZI')
IZ=Pauli('IZ')
XX=Pauli('XX')
XI=Pauli('XI')
IX=Pauli('IX')

observables=[ZZ,ZI,IZ,XX,XI,IX]

# %% [markdown]
# ## Step2: Optimize

# %% [markdown]
# ## Step3: Execute on the backend

# %%
from qiskit_aer.primitives import Estimator
estimator = Estimator()

job = estimator.run([qc] * len(observables), observables)

job.result()
# Out:
# EstimatorResult(values=array([ 1.        , -0.03515625, -0.03515625,  1.        , -0.02734375,
# ...

# %%
import matplotlib.pyplot as plt
data= ['ZZ','ZI','IZ','XX','XI','IX']
values = job.result().values

plt.plot(data,values, '-o')
plt.xlabel('observables')
plt.ylabel('Exception value')
plt.show()
